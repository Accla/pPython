# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#pPython-Tutorial-Using-LLSC-Jupyter-Notebook" data-toc-modified-id="pPython-Tutorial-Using-LLSC-Jupyter-Notebook-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>pPython Tutorial Using LLSC Jupyter Notebook</a></span></li><li><span><a href="#Set-up-Local-Machine-for-LLSC" data-toc-modified-id="Set-up-Local-Machine-for-LLSC-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Set up Local Machine for LLSC</a></span><ul class="toc-item"><li><span><a href="#Sanity-checks-from-the-local-machine" data-toc-modified-id="Sanity-checks-from-the-local-machine-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Sanity checks from the local machine</a></span></li></ul></li><li><span><a href="#pPython-Setup" data-toc-modified-id="pPython-Setup-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>pPython Setup</a></span><ul class="toc-item"><li><span><a href="#Create-pPython-configuraiton-directory,-HOME/ppython_conf,-on-LLSC-account" data-toc-modified-id="Create-pPython-configuraiton-directory,-HOME/ppython_conf,-on-LLSC-account-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Create pPython configuraiton directory, HOME/ppython_conf, on LLSC account</a></span><ul class="toc-item"><li><span><a href="#Verify-configuration-files-in-HOME/ppython_conf-on-LLSC-account" data-toc-modified-id="Verify-configuration-files-in-HOME/ppython_conf-on-LLSC-account-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Verify configuration files in HOME/ppython_conf on LLSC account</a></span></li></ul></li><li><span><a href="#Create-pPython-configuraiton-directory,-HOME/ppython_conf,-on-a-local-machine" data-toc-modified-id="Create-pPython-configuraiton-directory,-HOME/ppython_conf,-on-a-local-machine-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Create pPython configuraiton directory, HOME/ppython_conf, on a local machine</a></span><ul class="toc-item"><li><span><a href="#Verify-configuration-files-in-HOME/ppython_conf-on-a-local-machine" data-toc-modified-id="Verify-configuration-files-in-HOME/ppython_conf-on-a-local-machine-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Verify configuration files in HOME/ppython_conf on a local machine</a></span></li></ul></li></ul></li><li><span><a href="#Running-Examples-from-a-LLSC-System" data-toc-modified-id="Running-Examples-from-a-LLSC-System-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Running Examples from a LLSC System</a></span><ul class="toc-item"><li><span><a href="#Copy-pPython-examples-if-not-done-yet" data-toc-modified-id="Copy-pPython-examples-if-not-done-yet-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Copy pPython examples if not done yet</a></span></li><li><span><a href="#Change-the-current-working-directory-to-&quot;Mandelbrot&quot;-example" data-toc-modified-id="Change-the-current-working-directory-to-&quot;Mandelbrot&quot;-example-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Change the current working directory to "Mandelbrot" example</a></span></li><li><span><a href="#Review-files-in-the-&quot;Mandelbrot&quot;-example-directory" data-toc-modified-id="Review-files-in-the-&quot;Mandelbrot&quot;-example-directory-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Review files in the "Mandelbrot" example directory</a></span></li><li><span><a href="#Runing-as-an-interactive-job" data-toc-modified-id="Runing-as-an-interactive-job-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Runing as an interactive job</a></span><ul class="toc-item"><li><span><a href="#Old-style" data-toc-modified-id="Old-style-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Old style</a></span></li><li><span><a href="#Triples-mode" data-toc-modified-id="Triples-mode-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Triples mode</a></span></li></ul></li><li><span><a href="#Running-as-a-backgrounded-job-on-a-LLSC-system" data-toc-modified-id="Running-as-a-backgrounded-job-on-a-LLSC-system-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Running as a backgrounded job on a LLSC system</a></span><ul class="toc-item"><li><span><a href="#Old-style" data-toc-modified-id="Old-style-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Old style</a></span></li><li><span><a href="#Triples-mode:-array-job" data-toc-modified-id="Triples-mode:-array-job-4.5.2"><span class="toc-item-num">4.5.2&nbsp;&nbsp;</span>Triples mode: array job</a></span></li><li><span><a href="#Triples-mode:-srun-job" data-toc-modified-id="Triples-mode:-srun-job-4.5.3"><span class="toc-item-num">4.5.3&nbsp;&nbsp;</span>Triples mode: srun job</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # pPython Tutorial Using LLSC Jupyter Notebook
# <br>This Jupyter notebook demonstrates how to run pPython examples with different run time modes with LLGrid<br>
# <br><strong>The following variables are required to be set before start the rest of the section</strong>

# %%
import platform
import os

# Set the LLSC server name for samba/nfs service
LLSC_SERVER = 'txg-gridfs'

# Set GRID_MOUNT_PATH empty
GRID_MOUNT_PATH = ''

system_name = platform.system()
if system_name == 'Windows':
    USER = os.getenv('USERNAME')
else:
    USER = os.getenv('USER')

# %% [markdown]
# # Set up Local Machine for LLSC
# <br>
# <strong><font color='red'>Skip this section if you are using LLSC Jupyter Notebook server from LLSC portal service</font></strong>
# <br>
# <br>If you are not familiar with how to set up your local machine, please read the following link:</br>
# https://lldrpl1prod.llan.ll.mit.edu/llsc/setting-up-a-new-desktop

# %% [markdown]
# ## Sanity checks from the local machine
# <li>Can you execute "ssh <LLSC_login_node>" without prompting your login password for your LLSC account?</li>
# <li>Can you access your LLSC HOME directory from your local filesystem via a mapped/mounted path?</li>
# &nbsp&nbsp&nbsp&nbsp&nbsp<strong>- Define GRID_MOUNT_PATH</strong><br>
# &nbsp&nbsp&nbsp&nbsp&nbsp<strong>

# %%
# !ssh txg-login.llgrid.ll.mit.edu whoami
# Out:
# CH21778

# %%
# Check LLGrid Home directory is mapped on your local system
# if not, set up your local macione for LLSC environment
import platform
import os
import re
import psutil

# Extract mount path for LLGrid
system_name = platform.system()
if system_name == 'Windows':
    import win32net
    my_net_drive = win32net.NetUseEnum(None,0)[0]
    for drive in my_net_drive:
        # print('%s'%(drive['remote']))
        if re.search(LLSC_SERVER,drive['remote']):
            GRID_MOUNT_PATH = drive['local']
            break
else:
    USER = os.getenv('USER')
    for sdiskpart in psutil.disk_partitions(all=True):
        # print(sdiskpart)
        print('%s'%(sdiskpart[0]))
        if re.search(LLSC_SERVER,sdiskpart[0]):
            print('Mount path: %s'%(sdiskpart[1]))
            GRID_MOUNT_PATH = sdiskpart[1]
            break

# %% [markdown]
# # pPython Setup
# <br>You will need to create $HOME/ppython_conf directory and copy the following two files from pPython installation directory:</br>
# <li>grid_config_local.py</li>
# <li>pyMPI_Comm_settings_local.py</li>

# %%
# Check variables needed to set PPYTHON_HOME environment variable for local machine 

print('User: %s'%(USER))
print('GRID_MOUNT_PATH: %s'%(GRID_MOUNT_PATH))
# Out:
# User: CH21778
# GRID_MOUNT_PATH: Z:

# %% [markdown]
# ## Create pPython configuraiton directory, HOME/ppython_conf, on LLSC account
# <strong>Thess local configuraiton files are used by the pPython job launch performed on a LLGrid system</strong>

# %%
import os
import shutil
#
# Check if ~/ppython_conf directory exist on LLSC account
if os.path.exists('/etc/llgrid.id'):
    # On a LLSC machine
    # print('This Jupyter Notebook is running on a LLSC system')
    HOME = os.getenv('HOME')
    GRID_PPYTHON_CONFIG_DIR = HOME+'/ppython_conf'
    GRID_PPYTHON_EXAMPLE_DIR = HOME+'/ppython_examples'
    if os.path.exists(GRID_PPYTHON_CONFIG_DIR):
        print('%s directory already exists.'%(GRID_PPYTHON_CONFIG_DIR))
    else:
        print('Create %s directory.'%(GRID_PPYTHON_CONFIG_DIR))
        os.mkdir(GRID_PPYTHON_CONFIG_DIR)
        
    PPYTHON_HOME = HOME+os.sep+'llgrid_beta'+os.sep+'pPython'+os.sep+'latest'
    src_1 = PPYTHON_HOME+os.sep+'local'+os.sep+'grid_config_local.py'
    src_2 = PPYTHON_HOME+os.sep+'PythonMPI'+os.sep+'local'+os.sep+'pyMPI_Comm_settings_local.py'

    # Copy configuration files to PPYTHON_CONFIG_DIR
    shutil.copy(src_1, GRID_PPYTHON_CONFIG_DIR)
    shutil.copy(src_2, GRID_PPYTHON_CONFIG_DIR)
else:
    # On a local machine
    # print('This Jupyter Notebook is running outside of LLSC system')
    # LLSC HOME directory must be mapped/mounted
    if len(GRID_MOUNT_PATH) > 0 and os.path.exists(GRID_MOUNT_PATH):
        GRID_PPYTHON_CONFIG_DIR = GRID_MOUNT_PATH+'/ppython_conf'
        GRID_PPYTHON_EXAMPLE_DIR = GRID_MOUNT_PATH+'/ppython_examples'
        if os.path.exists(GRID_PPYTHON_CONFIG_DIR):
            print('%s directory already exists.'%(GRID_PPYTHON_CONFIG_DIR))
        else:
            print('Create %s directory.'%(GRID_PPYTHON_CONFIG_DIR))
            os.mkdir(GRID_PPYTHON_CONFIG_DIR)
            
        PPYTHON_HOME = GRID_MOUNT_PATH+os.sep+'llgrid_beta'+os.sep+'pPython'+os.sep+'latest'
        src_1 = PPYTHON_HOME+os.sep+'local'+os.sep+'grid_config_local.py'
        src_2 = PPYTHON_HOME+os.sep+'PythonMPI'+os.sep+'local'+os.sep+'pyMPI_Comm_settings_local.py'
            
        # Copy configuration files to PPYTHON_CONFIG_DIR
        shutil.copy(src_1, GRID_PPYTHON_CONFIG_DIR)
        shutil.copy(src_2, GRID_PPYTHON_CONFIG_DIR)
    else:
        print('ERROR: LLSC HOME directory is not mapped/mounted on the local machine.')
        print('       Finish Section 2 first.')
# Out:
# Create Z:/ppython_conf directory.

# %% [markdown]
# ### Verify configuration files in HOME/ppython_conf on LLSC account

# %%
#verify the configuration files in $HOME/ppython_conf directory
os.listdir(GRID_PPYTHON_CONFIG_DIR)
# Out:
# ['grid_config_local.py', 'pyMPI_Comm_settings_local.py']

# %% [markdown]
# ## Create pPython configuraiton directory, HOME/ppython_conf, on a local machine
# <strong>Thess local configuraiton files are used by the pPython job launch performed on a local machine</strong>

# %%
import os
import shutil
#
# Check if ~/ppython_conf directory exist on LLSC account
if os.path.exists('/etc/llgrid.id'):
    # On a LLSC machine
    print('This Jupyter Notebook is running on a LLSC system')
    print('Nothing needs to be done in this section since ~/ppython_conf is already configured in the previous seciton.')

else:
    # On a local machine
    # print('This Jupyter Notebook is running outside of LLSC system')
    HOME = os.getenv('HOME')
    LOCAL_PPYTHON_CONFIG_DIR = HOME+'/ppython_conf'
    if os.path.exists(LOCAL_PPYTHON_CONFIG_DIR):
        print('%s directory already exists on the local machine.'%(LOCAL_PPYTHON_CONFIG_DIR))
    else:
        print('Create %s directory on the local machine.'%(LOCAL_PPYTHON_CONFIG_DIR))
        os.mkdir(LOCAL_PPYTHON_CONFIG_DIR)
        
    # Copy configuration files to PPYTHON_CONFIG_DIR
    shutil.copy(src_1, LOCAL_PPYTHON_CONFIG_DIR)
    shutil.copy(src_2, LOCAL_PPYTHON_CONFIG_DIR)
# Out:
# C:\Users\ch21778/ppython_conf directory already exists on the local machine.

# %% [markdown]
# ### Verify configuration files in HOME/ppython_conf on a local machine

# %%
#verify the configuration files in $HOME/ppython_conf directory
if os.path.exists('/etc/llgrid.id'):
    print('This is already done in the previous step.')
else:
    print('List files in %s.'%(LOCAL_PPYTHON_CONFIG_DIR))
    print(os.listdir(LOCAL_PPYTHON_CONFIG_DIR))
# Out:
# List files in C:\Users\ch21778/ppython_conf.
# ['grid_config_local.py', 'pyMPI_Comm_settings_local.py', '__pycache__']

# %% [markdown]
# # Running Examples from a LLSC System

# %% [markdown]
# ## Copy pPython examples if not done yet
# <li><font color='red'>This step will be a lot slower if you are copying via a mounted path.</font></li>

# %%
import shutil

# Examples to be copied
src_examples = PPYTHON_HOME+os.sep+'examples'+os.sep
# Destination on LLGrid HOME
print('pPython examples will be copied from %s \nto the LLGrid account path, %s'%(src_examples,GRID_PPYTHON_EXAMPLE_DIR))

shutil.copytree(src_examples, GRID_PPYTHON_EXAMPLE_DIR, dirs_exist_ok=True)
# Out:
# pPython examples will be copied from Z:\llgrid_beta\pPython\latest\examples\
# to the LLGrid account path, Z:/ppython_examples
# 'Z:/ppython_examples'

# %%
# List examples directory

os.listdir(GRID_PPYTHON_EXAMPLE_DIR)
# Out:
# ['AddOne',
#  'Beamformer',
#  'Blurimage',
#  'FFT',
#  'HPL',
#  'IO',
#  'Mandelbrot',
#  'Param_Sweep',
#  'pBlurimage',
#  'RandomAccess',
#  'Speedtest',
#  'Stream',
#  'ZoomImage']

# %% [markdown]
# ## Change the current working directory to "Mandelbrot" example

# %%
import os
if os.path.exists('/etc/llgrid.id'):
    # On a LLSC machine
    os.chdir(HOME+os.sep+'ppython_examples'+os.sep+'Mandelbrot')
else:
    # On a local machine
    os.chdir(GRID_MOUNT_PATH+os.sep+'ppython_examples'+os.sep+'Mandelbrot')
    
print(os.getcwd())
# Out:
# Z:\ppython_examples\Mandelbrot

# %% [markdown]
# ## Review files in the "Mandelbrot" example directory

# %%
os.listdir()
# Out:
# ['pMandelbrot.py', 'RUN.py']

# %%
# Display RUN.py script, whcih demonstrates various job launch scenarios
f = open("RUN.py", "r")
print(f.read())
f.close()
# Out:
# """RUN.py
#
# Example to run a PythonMPI code with pPython
# To run, execute the following command.
#
#     python RUN.py
# """
#
# import os
# import sys
# import platform
#
# """
# Customization for the user runtime environment
# """
# # User name on LLGrid
# USER = 'ch21778'
#
# # Uncomment to enable the debug mode to see some additional output
# # os.environ['PPYTHON_DEBUG'] = 'yes'
#
# # Uncomment to disable the messaging kernel using the TMPDIR local filesystem (which is the default).
# os.environ['PPYTHON_LOCAL_FS'] = 'no'
#
# # Uncomment to enable the triples mode jobs
# os.environ['PPYTHON_TRIPLES'] = 'yes'
#
# # Uncomment to disable process bining
# # os.environ['PPYTHON_PROC_BIND'] = 'no'
#
# # Uncomment to use the git repository source code
# # os.environ['QA_ON_GIT'] = 'yes'
#
# # Specify whether to run on the grid with the scheduler or run locally without the scheduler
# RUN_ON_GRID = True  # True (run with grid installation) or False(run locally without scheduler)
# ...

# %% [markdown]
# ## Runing as an interactive job

# %%
# Sanity check before runnin the example

print('PPYTHON_HONE: %s'%(PPYTHON_HOME))
# Out:
# PPYTHON_HONE: Z:\llgrid_beta\pPython\latest

# %% [markdown]
# ### Old style

# %%
import sys

# Define PPYTHON_HOME environment variable
os.environ["PPYTHON_HOME"] = PPYTHON_HOME

# Add Python search path for pPython main function
PPYTHON_PATH = PPYTHON_HOME+os.sep+"src"
sys.path.append(PPYTHON_PATH)
# Import PythonMPI launch funciton
from pRUN import *

# Disable HDF5 file locking (Lustre parallel filesystem on LLSC)
os.environ["HDF5_USE_FILE_LOCKING"]="FALSE"

# By default, local filesystem based messaging kernel is enabled.
# For interactive job, disable it.
os.environ['PPYTHON_LOCAL_FS'] = 'no'

# PythonMPI script filename
py_file = 'pMandelbrot.py'
# Define number of MPI processes
n_proc = 4

# Launch pPython
pRUN( py_file, n_proc, 'grid' )
# Out:
# Minimum PythonMPI functions are loaded for pRUN().
# gridPython functions are loaded......
# grid_config_local: PPYTHON_HOME = Z:\llgrid_beta\pPython\latest
# --> grid_config_init: updated grid_config with a local configuration, C:\Users\ch21778\ppython_conf\grid_config_local.py.
# Running: pMandelbrot.py
# --> pyMPI_Comm_settings: updated machine_db_settings with a local configuration, C:\Users\ch21778\ppython_conf\pyMPI_Comm_settings_local.py.
# Launching MPI rank: 3 on grid_slurm_3.
# Launching MPI rank: 2 on grid_slurm_2.
# Launching MPI rank: 1 on grid_slurm_1.
# Launching MPI rank: 0 on 539990-MITLL.
#
# Submitted batch job 61811092
#
# grid_run: executing pMandelbrot.py in the current python process.
#
# Compute Time (sec)                 = 0.144278
# Launch+Comm Time (sec)             = 0.305248
# SUCCESS

# %% [markdown]
# ### Triples mode
# <strong>Show only needed changes from the previous old style run</strong>

# %%
# Define the triples mode parameters: [nnode, nppn, ntpp]
# nnode: number of compute nodes
# nppn:  number of pPython processes on each compute node
# ntpp:  number of threads per process

n_proc_triples = [4,2,24]

# Launch pPython
pRUN( py_file, n_proc_triples, 'grid-xeon-e5' )
# Out:
# grid_config_local: PPYTHON_HOME = Z:\llgrid_beta\pPython\latest
# --> grid_config_init: updated grid_config with a local configuration, C:\Users\ch21778\ppython_conf\grid_config_local.py.
#
# ...
#
# Your triples mode job [4,2,24] requests 2*24 = 48 < 28 threads on the node.
# You are launching more threads than the 28 cores on the node you requested, which may be sub-optimal.
# See https://supercloud.mit.edu/faq#triples-warning for more information.
#
# Running: pMandelbrot.py
# ... scancel 61811092
# --> pyMPI_Comm_settings: updated machine_db_settings with a local configuration, C:\Users\ch21778\ppython_conf\pyMPI_Comm_settings_local.py.
# Launching MPI rank: 7 to 6 on grid_slurm_4.
# Launching MPI rank: 5 to 4 on grid_slurm_3.
# Launching MPI rank: 3 to 2 on grid_slurm_2.
# Launching MPI rank: 1 to 1 on grid_slurm_1.
# Launching MPI rank: 0 to 0 on 539990-MITLL.
#
# Submitted batch job 61811095
#
# grid_run: executing pMandelbrot.py in the current python process.
#
# ...

# %% [markdown]
# ## Running as a backgrounded job on a LLSC system

# %% [markdown]
# ### Old style
# <strong>Show only needed changes from the previous old style run</strong>

# %%
# Launch pPython with '&' after grid

pRUN( py_file, n_proc, 'grid&' )
# Out:
# grid_config_local: PPYTHON_HOME = Z:\llgrid_beta\pPython\latest
# --> grid_config_init: updated grid_config with a local configuration, C:\Users\ch21778\ppython_conf\grid_config_local.py.
# Running: pMandelbrot.py
# ... scancel 61811095
# --> pyMPI_Comm_settings: updated machine_db_settings with a local configuration, C:\Users\ch21778\ppython_conf\pyMPI_Comm_settings_local.py.
# Launching MPI rank: 3 on grid_slurm_4.
# Launching MPI rank: 2 on grid_slurm_3.
# Launching MPI rank: 1 on grid_slurm_2.
# Launching MPI rank: 0 on grid_slurm_1.
#
# Submitted batch job 61811099

# %%
# Check the PythonMPI subdirectory, which is automatically created

os.listdir('PythonMPI')
# Out:
# ['MPI_COMM_WORLD.pkl',
#  'pid.slurm.61811099',
#  'pMandelbrot.0.out',
#  'pMandelbrot.1.out',
#  'pMandelbrot.2.out',
#  'pMandelbrot.3.out',
#  'pRUN.err',
#  'pRUN.log',
#  'PythonMPIdefs0.py',
#  'PythonMPIdefs1.py',
#  'PythonMPIdefs2.py',
#  'PythonMPIdefs3.py',
#  'Unix_Commands.1.sh',
#  'Unix_Commands.2.sh',
#  'Unix_Commands.3.sh',
#  'Unix_Commands.4.sh',
#  'Unix_Commands.sh']

# %%
#Check the standard output from the leader process (Pid = 0)

f = open("PythonMPI"+os.sep+"pMandelbrot.0.out", "r")
print(f.read())
f.close()
# Out:
# Compute Time (sec)                 = 0.036224
# Launch+Comm Time (sec)             = 0.112744
#
#
# SUCCESS

# %% [markdown]
# ### Triples mode: array job
# <strong>Immediate launch as an array job when the requested resources are available</strong><br>
# <strong>Show only needed changes from the previous old style run</strong>

# %%
# Define number of MPI processes
n_proc_triples = [4,2,24]

# Launch pPython
pRUN( py_file, n_proc_triples, 'grid=xeon-e5&' )
# Out:
# grid_config_local: PPYTHON_HOME = Z:\llgrid_beta\pPython\latest
# --> grid_config_init: updated grid_config with a local configuration, C:\Users\ch21778\ppython_conf\grid_config_local.py.
#
# ...
#
# Your triples mode job [4,2,24] requests 2*24 = 48 < 28 threads on the node.
# You are launching more threads than the 28 cores on the node you requested, which may be sub-optimal.
# See https://supercloud.mit.edu/faq#triples-warning for more information.

# %%
# Check the PythonMPI subdirectory, which is automatically created

os.listdir('PythonMPI')

# %% [markdown]
# ### Triples mode: srun job
# <strong>pPython job cna be launched as a batch job using srun when the requested resources are NOT available or explicitly requested</strong><br>
# <strong><font color='red'>If one task fail, the entire job will exit</font></strong><br>

# %%
# Enforce to submit a backgrounded triples mode job as a batch job using srun
os.environ['PPYTHON_SRUN'] = 'YES'

# To check the actual job submission command
os.environ['PPYTHON_DEBUG'] = 'YES'

# %%
# Define number of MPI processes
n_proc_triples = [4,2,24]

# Launch pPython
pRUN( py_file, n_proc_triples, 'grid-xeon-e5&' )

# %%
# Check the PythonMPI subdirectory, which is automatically created

os.listdir('PythonMPI')

# %%
#Check the standard output from the leader process (Pid = 0)

my_list = os.listdir('PythonMPI')
for entry in my_list:
    if re.search('p0-',entry):
        #Find the subdirectory for the first compute node 
        subdir_name = entry
        break
#
my_list = os.listdir('PythonMPI')
pidstr = '0'
std_output_file = 'PythonMPI'+os.sep+subdir_name+os.sep+'pMandelbrot.'+pidstr+'.out'
print('Read file, %s'%(std_output_file))
print('')
f = open(std_output_file, "r")
print(f.read())
f.close()

# %%
# Review the job submission script for pPython

job_submit_script = 'PythonMPI'+os.sep+'Unix_Commands.sh'
f = open(job_submit_script, "r")
print(f.read())
f.close()

# %%
# Review the job management script on a compute node

script_id = 1
node_exec_script = 'PythonMPI'+os.sep+'Unix_Commands.'+str(script_id)+'.sh'
f = open(node_exec_script, "r")
print(f.read())
f.close()
